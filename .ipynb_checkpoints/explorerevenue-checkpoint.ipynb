# %%
import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline
from fbprophet import Prophet
from fbprophet.diagnostics import cross_validation, performance_metrics
from fbprophet.plot import plot_cross_validation_metric
from time import strptime

# %% [markdown]
# Import the data (may need to install the necessary excel addon for read_excel):

# %%
df = pd.read_excel('revenue.xls')

# %%
df.head()
# Out:
#   Net Revenue USD for FY18 Revenue Budget (Fiscal Month)       Unnamed: 1  \
# 0                                                NaN      Casual DateLine
# 1                                                NaN      Net Revenue USD
# 2                                         FY2010-Jan               377939
# 3                                         FY2010-Feb               337159
# 4                                         FY2010-Mar               387546
#
#         Unnamed: 2       Unnamed: 3       Unnamed: 4       Unnamed: 5  \
# 0         Fonochat     GuySpy Voice  InteractiveMale        LiveLinks
# 1  Net Revenue USD  Net Revenue USD  Net Revenue USD  Net Revenue USD
# 2           320808              NaN           880817      1.80757e+06
# 3           335724              NaN           837174      1.76726e+06
# 4           384028              NaN           915134      1.89768e+06
#
#         Unnamed: 6       Unnamed: 7
# 0   TangoPersonals         Vibeline
# 1  Net Revenue USD  Net Revenue USD
# 2           259958           258467
# 3           256983           275816
# 4           282160           279183

# %% [markdown]
# Ok, drop rows 0 and 2, and replace NaN's with zeroes:

# %%
df = pd.read_excel('revenue.xls', skiprows=[0,2])
df.fillna(0, inplace=True)

# %%
df.tail()
# Out:
#      Unnamed: 0  Casual DateLine     Fonochat  GuySpy Voice  InteractiveMale  \
# 103  FY2018-Aug     86893.175322  137636.0391   160546.3467     77545.124952
# 104  FY2018-Sep         0.000000       0.0000        0.0000         0.000000
# 105  FY2018-Oct         0.000000       0.0000        0.0000         0.000000
# 106  FY2018-Nov         0.000000       0.0000        0.0000         0.000000
# 107  FY2018-Dec         0.000000       0.0000        0.0000         0.000000
#
#          LiveLinks  TangoPersonals     Vibeline
# 103  699939.017528    61203.852129  92391.97591
# 104       0.000000        0.000000      0.00000
# 105       0.000000        0.000000      0.00000
# 106       0.000000        0.000000      0.00000
# 107       0.000000        0.000000      0.00000

# %% [markdown]
# Drop empty rows as well as last actual month since it was incomplete:

# %%
df.drop(range(103,108),inplace=True)

# %% [markdown]
# Rename the date column using df.rename(columns=dict, inplace=True)
# Note: this syntax for merging dicts x, y is new to python 3.5:  z = {**x, **y}

# %%
df.rename(columns={**{'Unnamed: 0': 'Date'}, **{df.columns[k]: df.columns[k] for k in range(1, len(df.columns)) }}, inplace=True)

# %% [markdown]
# Format the date column as YYYY-MM string, then convert to datetime:

# %%
df['Date'] = df['Date'].apply(lambda x: x[2:7] + str(strptime(x[-3::],"%b").tm_mon).zfill(2))

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# Set date as the index:

# %%
df.set_index('Date', inplace=True)

# %% [markdown]
# A quick plot of the data:

# %%
df.plot(legend=False, figsize=(14,7))
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# Let's add a column for Total Revenue:

# %%
df['totalrev'] = df.sum(axis='columns')

# %% [markdown]
# We'll warm up with a forecast of the LiveLinks brand.
#
# Instantiate a new Prophet object:

# %%
def df_for_forecast(df, column):
    """Given dataframe df indexed by datetime, 
    gives correctly formatted input for Prophet.fit(), 
    namely a dataframe with two columns:
    'ds'=date and 'y'=seriesdata 
    Here seriesdata is contained in the column of df
    called 'column' (string)  """
    return pd.DataFrame({'ds': df.index, 'y': df[column]}, columns=['ds', 'y'])

# %%
LiveLinks_ts = Prophet(seasonality_mode='multiplicative')
LiveLinks_ts.fit(df_for_forecast(df, 'LiveLinks'))
# Out:
# INFO:fbprophet.forecaster:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\JamieG\AppData\Local\conda\conda\envs\ds\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
LiveLinks_future = LiveLinks_ts.make_future_dataframe(periods=12, freq='M')
LiveLinks_future.tail()
# Out:
#             ds
# 110 2019-02-28
# 111 2019-03-31
# 112 2019-04-30
# 113 2019-05-31
# 114 2019-06-30

# %%
LiveLinks_forecast=LiveLinks_ts.predict(future)

# %%
fig = LiveLinks_ts.plot(LiveLinks_forecast)

# %%
def fitandforecast(df, column):
    ts = Prophet(seasonality_mode='multiplicative')
    ts.fit(df_for_forecast(df, column))
    future = ts.make_future_dataframe(periods=18, freq='M')
    forecast = ts. predict(future)
    return ts, forecast

# %%
ll, llforecast = fitandforecast(df, 'LiveLinks')
# Out:
# INFO:fbprophet.forecaster:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\JamieG\AppData\Local\conda\conda\envs\ds\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
llforecast.columns
# Out:
# Index(['ds', 'trend', 'yhat_lower', 'yhat_upper', 'trend_lower', 'trend_upper',
#        'multiplicative_terms', 'multiplicative_terms_lower',
#        'multiplicative_terms_upper', 'yearly', 'yearly_lower', 'yearly_upper',
#        'additive_terms', 'additive_terms_lower', 'additive_terms_upper',
#        'yhat'],
#       dtype='object')

# %%
fig2 = ll.plot(llforecast)
fig2ax=plt.gca()
fig2ax.set_xlim(pd.Timestamp('2011-09'), pd.Timestamp('2020-06'))
fig2ax.set_ylim(top=1850000, bottom=000000)
# Out:
# (0, 1850000)

# %%
gross, gross_forecast = fitandforecast(df, 'totalrev')
# Out:
# INFO:fbprophet.forecaster:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\JamieG\AppData\Local\conda\conda\envs\ds\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
fig_gross = gross.plot(gross_forecast)
gross_ax = plt.gca()
gross_ax.set_xlim(pd.Timestamp('2012'), pd.Timestamp('2020'))
gross_ax.set_ylim([0,4000000])
# Out:
# (0, 4000000)

# %%
gross_comps=gross.plot_components(gross_forecast)

# %%
gross_forecast[gross_forecast['ds'] >= pd.to_datetime('2012-01-01')].head()
# Out:
#            ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 24 2012-01-01  3.334140e+06  3.085289e+06  3.231243e+06  3.334140e+06
# 25 2012-02-01  3.286946e+06  3.129596e+06  3.270385e+06  3.286946e+06
# 26 2012-03-01  3.242796e+06  3.397941e+06  3.529452e+06  3.242796e+06
# 27 2012-04-01  3.195986e+06  3.129259e+06  3.266021e+06  3.195986e+06
# 28 2012-05-01  3.150685e+06  3.133646e+06  3.270224e+06  3.150685e+06
#
#      trend_upper  multiplicative_terms  multiplicative_terms_lower  \
# 24  3.334140e+06             -0.052958                   -0.052958
# 25  3.286946e+06             -0.025744                   -0.025744
# 26  3.242796e+06              0.067343                    0.067343
# 27  3.195986e+06              0.002255                    0.002255
# 28  3.150685e+06              0.015785                    0.015785
#
#     multiplicative_terms_upper    yearly  yearly_lower  yearly_upper  \
# 24                   -0.052958 -0.052958     -0.052958     -0.052958
# 25                   -0.025744 -0.025744     -0.025744     -0.025744
# 26                    0.067343  0.067343      0.067343      0.067343
# 27                    0.002255  0.002255      0.002255      0.002255
# 28                    0.015785  0.015785      0.015785      0.015785
#
#     additive_terms  additive_terms_lower  additive_terms_upper          yhat
# 24             0.0                   0.0                   0.0  3.157569e+06
# 25             0.0                   0.0                   0.0  3.202325e+06
# 26             0.0                   0.0                   0.0  3.461177e+06
# 27             0.0                   0.0                   0.0  3.203194e+06
# 28             0.0                   0.0                   0.0  3.200419e+06

# %%
fono, fono_forecast = fitandforecast(df, 'Fonochat')
fig_fono = fono.plot(fono_forecast)
fono_ax = plt.gca()
fono_ax.set_xlim(pd.Timestamp('2012'), pd.Timestamp('2020'))
fono_ax.set_ylim([0,500000])
# Out:
# INFO:fbprophet.forecaster:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\JamieG\AppData\Local\conda\conda\envs\ds\lib\site-packages\pystan\misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# (0, 500000)

# %%
fono_comps = fono.plot_components(fono_forecast[fono_forecast['ds'] >= pd.to_datetime('2012-01-01')])

# %%
revTS = Prophet(seasonality_mode='multiplicative')
revTS.fit(df[['date', 'totalrev']].rename(columns={"date": "ds", "totalrev": "y"}))
# Out:
# INFO:fbprophet.forecaster:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
futurerev=revTS.make_future_dataframe(periods=18, freq='M')

# %%
revforecast = revTS.predict(futurerev)

# %% [raw]
# revfig, ax = plt.subplots(1,1,1)
# revTS.plot(revforecast, ax=ax)
# plt.show()

# %%
revfig = plt.figure()
ax = revfig.add_subplot(111)
revplot=revTS.plot(revforecast, ax=ax)
ax.set_xlim(left=ax.get_xlim()[0]+(ax.get_xlim()[1]-ax.get_xlim()[0])/2)
ax.set_ylim(top=2800000)
# Out:
# (1340983.3278656015, 2800000)

# %%
revfig, ax = plt.subplots()
revTS.plot(revforecast, ax=ax)

# %%
revTS.plot_components(revforecast);

# %%
axx=df[['date', 'totalrev']].rename(columns={"date": "ds", "totalrev": "y"}).plot(figsize=(12,4))

# %%
df[['date', 'totalrev']].plot(figsize=(12,4))

# %%
    fcst_t = fcst['ds'].dt.to_pydatetime()
????
